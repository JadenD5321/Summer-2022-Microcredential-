# %% [markdown]
# <a href="https://colab.research.google.com/github/JadenD5321/Summer-2022-Microcredential-/blob/main/InClasslabAssignment(Iris).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Identify the problem

# %% [markdown]
# In this project, I will be formulating a conductive analysis give the dataset where we have to classify the class of Iris based on Sepal Length, Sepal Width, Petal Length and Petal Width.

# %% [markdown]
# # Task 2: Load the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# # Task 3: Load the Data

# %%
df= pd.read_csv('https://raw.githubusercontent.com/JadenD5321/Machine-Learning-Data/main/iris.csv')

# %% [markdown]
# #Task 4: EDA (Exploratory Data Analysis)

# %%
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.isnull()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Class
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
df.isnull().value_counts()
# Out:
# Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Class
# False         False        False         False        False    150
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Class'], dtype='object')

# %%
sns.pairplot(df, hue='Class',palette='coolwarm')

# %% [markdown]
# # Task 5: Data Visualizations
#
# We need 5 data visualizations

# %%
sns.countplot(x='Class', data=df)

# %%
sns.scatterplot(x='Petal_Width', y='Petal_Length', hue='Class',data=df)

# %%
sns.boxplot(x = 'Sepal_Length', y = 'Sepal_Width', data = df, palette = 'winter')

# %% [markdown]
# Based on this data, we can observe that the length is increasing overtime. I am using this figure to compare different features. It also emphasizes how far the pedals are away from each other.

# %%
sns.stripplot(x = 'Petal_Length', y = 'Petal_Width', data = df, palette = 'winter')

# %%
sns.pairplot(df, hue='Class')

# %%
sns.countplot(x='Sepal_Width', data=df)

# %% [markdown]
# # Task 6: Train, Test, Spilt

# %% [markdown]
# We have to change the variable in class in order for the data to be transformed into different kind of models

# %%
df['Class'] = df['Class'].replace(['Setosa'],'1')

# %%
df['Class'].replace(['Versicolor'],'2')
# Out:
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: Class, Length: 150, dtype: object

# %%
df['Class'].replace(['Virginica'],'3')
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Class, Length: 150, dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(df.drop('Class',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('Class', axis=1))

# %%
scaled_features
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
df_feat= pd.DataFrame(scaled_features,columns=df.columns[:-1])

# %%
df_feat.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(scaled_features, df['Class'],test_size=0.30)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# #Task 7: Conducting a Logistic Regression

# %% [markdown]
# some resources I used to help me make it
# https://archive.ics.uci.edu/ml/datasets/Iris
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/iris/

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:, [0, 4]].values
y = df.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1)

# %%
classifier = LogisticRegression(random_state=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-699-bedefee2c99c> in <module>()
#       1 logmodel = LogisticRegression(max_iter=1000)
# ----> 2 logmodel.fit(X_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
pred= knn.predict(X_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#   Versicolor       0.94      0.89      0.91        18
#    Virginica       0.86      0.92      0.89        13
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.94      0.93        45
# weighted avg       0.94      0.93      0.93        45

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[14  0  0]
#  [ 0 16  2]
#  [ 0  1 12]]

# %% [markdown]
# #KNN Model

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
#scaler.fit(df)

# %%
#scaled_features = scaler.transform(df)

# %%
# df_feat = pd.DataFrame(scaled_features, columns=df.columns[:])
#df_feat.head()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Class
# 0           5.1          3.5           1.4          0.2     1
# 1           4.9          3.0           1.4          0.2     1
# 2           4.7          3.2           1.3          0.2     1
# 3           4.6          3.1           1.5          0.2     1
# 4           5.0          3.6           1.4          0.2     1

# %%
X_train, X_test, y_train, y_test = train_test_split(df, df['Class'], test_size = 0.30)

# %%
model = LogisticRegression()
model.fit(scaled_x_train, y_train)
# Out:
# LogisticRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
scaler = StandardScaler() Making a scaler
scaler.fit(X_train)
scaled_x_train = scaler.transform(X_train)
scaled_x_test = scaler.transform(X_test)
# Out:
#   File "<ipython-input-764-0a57a4930170>", line 1
#     scaler = StandardScaler() Making a scaler
#                                    ^
# SyntaxError: invalid syntax

# %%
model = LogisticRegression()
model.fit(scaled_x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(scaled_x_test)
y_pred
# Out:
# array(['Virginica', 'Virginica', 'Virginica', 'Virginica', 'Virginica',
#        'Virginica', 'Versicolor', '1', 'Versicolor', 'Virginica',
#        'Versicolor', 'Virginica', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Virginica', 'Virginica', '1', 'Virginica',
#        'Versicolor', 'Virginica', 'Virginica', 'Versicolor', 'Virginica',
#        'Versicolor', 'Virginica', 'Versicolor', 'Virginica', 'Versicolor',
#        'Virginica', 'Versicolor', 'Versicolor', 'Virginica', 'Virginica',
#        'Versicolor', 'Virginica', 'Versicolor', 'Virginica', 'Versicolor',
#        'Virginica', 'Versicolor', 'Virginica', 'Virginica', 'Virginica',
#        'Virginica'], dtype=object)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        18
#   Versicolor       0.35      0.43      0.39        14
#    Virginica       0.35      0.69      0.46        13
#
#     accuracy                           0.33        45
#    macro avg       0.23      0.37      0.28        45
# weighted avg       0.21      0.33      0.25        45

# %% [markdown]
# #Error Rate

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = knn, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: nan %
# Standard Deviation: nan %
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py", line 198, in fit
#     return self._fit(X, y)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py", line 400, in _fit
# ...

# %%
error_rate
# Out:
# []
